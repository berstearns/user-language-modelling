# %%
import sys
import pickle
sys.path.append("..")
import tools
from os.path import join
from tools import process_EFCAMDAT_XML
from collections import Counter

# %%
with open("./learners_by_n.pickle","rb") as learners_by_n_outf, open("./learners_count_by_n.pickle","rb") as learners_outf :
    groups = pickle.load(learners_by_n_outf)
    count = pickle.load(learners_outf)

# %%
for k, v in sorted(count.items(), key= lambda x: x[1], reverse=True):
    print(k,v)
# Out:
# 1 51809
# 2 24257
# 3 18612
# 4 12031
# 5 8511
# 7 7226
# 6 6229
# 8 4993
# 9 4286
# 10 4004
# 11 3042
# 12 2565
# 13 2481
# 15 2008
# 14 1809
# 16 1772
# 17 1542
# 19 1427
# 18 1375
# 20 1132
# 21 992
# 24 916
# 23 889
# 22 886
# 25 843
# 26 752
# 27 675
# 28 559
# 30 547
# 29 546
# 31 481
# 32 455
# 33 402
# 34 391
# 35 356
# 37 346
# 36 322
# 39 264
# 40 240
# 38 232
# 41 217
# 42 185
# 43 168
# 45 150
# 44 144
# 46 127
# 47 126
# 48 122
# 50 110
# 49 101
# 56 82
# 51 81
# 53 64
# 54 63
# 52 61
# 57 50
# 55 50
# 59 47
# 58 45
# 62 40
# 60 39
# 61 36
# 64 32
# 65 31
# 63 25
# 73 22
# 67 21
# 66 20
# 72 20
# 68 19
# 70 15
# 75 15
# 80 14
# 71 14
# 79 14
# 69 12
# 76 11
# 77 11
# 78 9
# 82 9
# 74 8
# 84 7
# 89 7
# 100 6
# 96 6
# 98 5
# 81 5
# 95 5
# 86 5
# 90 4
# 85 4
# 87 4
# 92 4
# 83 4
# 94 3
# 97 3
# 93 2
# 127 2
# 110 2
# 91 2
# 103 2
# 88 2
# 112 2
# 121 2
# 104 2
# 108 2
# 113 2
# 99 2
# 101 2
# 105 1
# 102 1
# 119 1
# 129 1
# 109 1
# 115 1
# 118 1
# 177 1
# 114 1
# 136 1

# %%
groups[121][0]
# Out:
# {'id': '21407',
#  'nationality': 'mx',
#  'writings': [{'id': '289773',
#    'level': '1',
#    'unit': '1',
#    'topic_id': '1',
#    'topic_name': 'Introducing yourself by email',
#    'grade': '96',
#    'text': "\n      Hello. My name is Daniela. I have twenty-three years old. I'm from is Guadalajara, Mexico. I want to learning English. Nice to be here.\n    "},
#   {'id': '289774',
#    'level': '1',
#    'unit': '2',
#    'topic_id': '2',
#    'topic_name': 'Taking inventory in the office',
#    'grade': '100',
#    'text': '\n      There are 30 pens, there are 15 pencils, there are 12 desks, there are 14 chairs, there are 16 headphones and there is one table. Daniela\n    '},
#   {'id': '289775',
#    'level': '1',
#    'unit': '3',
#    'topic_id': '3',
#    'topic_name': 'Writing an online profile',
#    'grade': '92',
#    'text': '\n      Hi!'},
#   {'id': '289776',
#    'level': '1',
#    'unit': '4',
#    'topic_id': '4',
# ...
